# %% [markdown]
# ##복습
# ##매개변수와 인수
#
# 매개변수와 인수는 혼용해서 사용되는 헷갈리는 용어!!!
# 매개변수는 함수에 입력으로 전달된 값을 받는 변수
# 인수는 함수를 호출할때 전달하는 입력값을 의미

# %% [markdown]
# ##입력값과 결과값에 따른 함수 형태
#
# 함수의 형태는 입력값과 결과값의 존재유무에 따라 4가지 유형으로 나뉩니다.

# %% [markdown]
# ##지역변수, 전역변수
#
# 함수 내에서 생성한 변수를 '지역변수', 함수밖에서 생성한 변수를 '전역변수'이라 함.

# %%
##예제> dt스쿨 최저연령은? 
alist = {
    '1팀':[25,39,29,22], 
    '2팀':[27,24,25,29,25], 
    '3팀':[25,26,23,23,28,27],
    '4팀':[21,23,30],
    '5팀':[26,41,31,21,34,27],
    '6팀':[21,29,27,25,25]}
age_li = []
for i,v in alist.items():
    print(f'{i}의 최저연령은{min(v)} 최고연령은 {max(v)}')
    age_li.extend(v)
    # print(age_li)
print(f'DT스쿨 최저연령은{min(age_li)} 최고연령은 {max(age_li)}')
# Out:
# 1팀의 최저연령은22 최고연령은 39
# 2팀의 최저연령은24 최고연령은 29
# 3팀의 최저연령은23 최고연령은 28
# 4팀의 최저연령은21 최고연령은 30
# 5팀의 최저연령은21 최고연령은 41
# 6팀의 최저연령은21 최고연령은 29
# DT스쿨 최저연령은21 최고연령은 41

# %%
##예제> dt스쿨 평균연령은? ##딕셔너리
alist = {
    '1팀':[25,39,29,22], 
    '2팀':[27,24,25,29,25], 
    '3팀':[25,26,23,23,28,27] ##round값 -- 을 이용하여 평균값을 
    '4팀':[21,23,30]
    '5팀':[26,41,31,21,34,27],
    '6팀':[21,29,27,25,25]}
age_li = []
for i,v in alist.items():
    print(f'{i}의 최저연령은{min(v)} 최고연령은 {max(v)}')
    age_li.extend(v)
    # print(age_li)
print(f'DT스쿨 최저연령은{min(age_li)} 최고연령은 {max(age_li)}')
print()

# %%
##예제>우리팀 캐릭터 사전 만들기 
#닉네임에 따른 사전을 만듭니다

team_dic={'딸기':[21,161,'베이킹'],'수박':[23,160,'바이올린'], '바나나':[30,175,'운동']}
a = input()
b_list = team_dic[a]
print(f'우리 {a}님을 소개합니다. {a}님은 {b_list[2]}를 좋아해요.')
print(f'나이는 {b_list[0]}! {b_list[1]}의 키를 가졌지만 신기하게도 취미는 {b_list[2]}예요!!!')
print(f'사랑스러운 {a}님 이시네요')
# Out:
# 딸기
# 우리 딸기님을 소개합니다. 딸기님은 베이킹를 좋아해요.
# 나이는 21! 161의 키를 가졌지만 신기하게도 취미는 베이킹예요!!!
# 사랑스러운 딸기님 이시네요

# %%
##예제>우리팀 캐릭터 사전 만들기 
#닉네임에 따른 사전을 만듭니다

team_dic={'':['공부',90,30,40],'':['놀기',50,20,14]}
a = input()
b_list = team_dic[a]
print(f'우리 {a}님을 소개합니다. {a}님은 {b_list[0]}를 좋아해요.')
print(f'체력은 {b_list[1]}! {b_list[2]}세의 신체연령에 신기하게도 정신연령은 {b_list[3]}세!!!')
print(f'사랑스러운 {a}님 이시네요')

# %%
##문자열 나누기
#문자열.split() 함수는 문자열을 일정한 규칙으로 잘라서 리스트로 만들어 주는 함수
text = '문자열 나누기'
li = text.split(sep='.')
li
# Out:
# ['문자열 나누기']

# %%
##'구분자' join(리스트) 함수는 리스트에 있는 요소 하나하나를 합쳐서 하나의 문자열로 바꾸어 반환
text2 = '.'.join(li) # ' ' 구분자
text2
# Out:
# '문자열 나누기'

# %%
#딕셔너리 값 가져오기
#딕셔너리 값이 리스트, 딕셔너리 일때
alist = {
    '키1':['값1','값2']
    '키2':['값3','값4']
    '키3':['값5','값6']
    '키4':{'키':100}}
print(list(alist['키1']))
print(alist['키4']['키'])
# Out:
#   File "<ipython-input-12-85c6e90d6275>", line 5
#     '키2':['값3','값4']
#        ^
# SyntaxError: invalid syntax

# %%
alist = {
    '키1':['값1', '값2'], 
    '키2':['값3', '값4'], 
    '키3':['값5', '값6'],
    '키4':{'키':100}}
print(list(alist['키1']))
print(alist['키4']['키']
# Out:
#   File "<ipython-input-13-12201b0eb11d>", line 7
#     print(alist['키4']['키']
#                           ^
# SyntaxError: unexpected EOF while parsing

# %%
##얼굴인식
#얼굴 정보의 검출,분석,인식, 복원
#인공지능 기술
#네트워크 대역폭
#방대한 데이터 플랫폼          --> 모니터링, 출입통제, 생체인증 등 활용

# %% [markdown]
# ##OpenAPI
# open application programming interface의 약어로서 누구나 사용할 수 있도록 공개된 api
#
# Open API를 활용하기 위해서 반드시 '서비스키'를 발급받아야 함.
#
# 사용자 --> 키 --> 데이터제공자

# %% [markdown]
# ##네이버오픈 API
#
# 오픈API(응용프로그램 프로그래밍 인터페이스)
#
# 오픈API는 누구나 사용할 수 있도록 공개된 API
#
# 하나의 웹 사이트에서 자신이 가진 기능을 이용할 수 있도록 공개한 프로그래밍 인터페이스
#
# 개발자에게 응용소프트웨어나 웹 서비스에 프로그래밍

# %% [markdown]
# ##네이버 얼굴 인식 api
#
# clova
#
# 얼굴과 관련된 다양한 정보를 제공하는 얼굴 인식 api
# 얼굴을 인식하거나 얼굴 감지를 이용한 애플리케이션을 만들 때 유용한 api 유명인 얼굴 인식 및 정확한 얼굴 감지 기능
#
# 이미지 속의 얼굴과 가장 닮은 유명인을 찾거나, 얼굴의 윤곽과 눈/코/입 위치

# %% [markdown]
# api선택(api를 사용 선택) --> api사용신청(허가받기) --> api사용(api기본정보확인 -예제코드 확인 후 사용)

# %% [markdown]
# ##팀과제
# 네이버 오픈 api를 이용하여 검색을 요청하고 결과 화면 출력
#
# 본인의 얼굴 인식 나이를 확인하고 출력
# 팀원 모두의 얼굴인식 나이를 측정하고 평균값을 측정
# 팀과제 해결방법 요약 내용자료와 함께 colab파일 제출

# %%
from google.colab import drive### 구글 드라이브랑 연결하기 
drive.mount('/content/drive') ###드라이브에 파일 업로드 가능 사용하고자 하는 파일의 경로복사를 해야함(마우스 왼쪽 버튼)
# Out:
# Mounted at /content/drive

# %%
import os
import sys
import requests


# 등록된 client_id, client_secret 정보를 입력합니다.
client_id = "yBwPM0bgoQTE7MzqhxmM"
client_secret = "2HiUBFvSq_"

# 얼굴 사진을 통한 나이 추정을 위해서는 아래 url을 사용합니다. (face: 얼굴 분석, celebrity: 닮은 유명인 찾기)
url = "https://openapi.naver.com/v1/vision/face" 
# url = "https://openapi.naver.com/v1/vision/celebrity" 

# 분석할 이미지의 파일명을 입력합니다./
files = {'image': open('/content/drive/MyDrive/그림1.jpg', 'rb')}

# API 입력 설정
headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret }

# API 사용
response = requests.post(url,  files=files, headers=headers)
rescode = response.status_code

if (rescode==200):
    # 결과물 출력
    print (response.text)
else:
    print("Error Code:" + str(rescode))
# Out:
# {"info":{"size":{"width":453,"height":448},"faceCount":1},"faces":[{"celebrity":{"value":"최진실","confidence":0.01}}]}

# %%
# json 형식을 사용하기 위하여 import 합니다.
import json

# loads 함수를 사용하여 json으로 변환합니다.
result = json.loads(response.text)
result
# Out:
# {'faces': [{'celebrity': {'confidence': 0.01, 'value': '최진실'}}],
#  'info': {'faceCount': 1, 'size': {'height': 448, 'width': 453}}}

# %%
#팀원 평균
# 성민지"age":{"value":"23~27","confidence":0.804936}
# 김선민'age': {'confidence': 0.579662, 'value': '21~25'
# 이승은"age":{"value":"18~22","confidence":0.700819}
team_age = {
    '성민지': [23,27],
    '김선민': [21,25],
    '이승은': [18,22]}
tage = [] 
for i,v in team_age.items():
    b = (min(v)+max(v))/2
    print(f'{i}의 평균연령은 {b}')
    tage.extend(v)
print(f'4팀 최저연령은{min(tage)} 최고연령은 {max(tage)} 평균연령은 {b}')
print()
# Out:
# 성민지의 평균연령은 25.0
# 김선민의 평균연령은 23.0
# 이승은의 평균연령은 20.0
# 4팀 최저연령은18 최고연령은 27 평균연령은 20.0

# %%
alist = {
    '민지':[23,27], 
    '승은':[18,22], 
    '선민':[21,25]}
age_li = []
for i,v in alist.items():
    a = (min(v)+max(v))/2
    print(f'{i}의 평균연령은 {a}')
    age_li.extend(v)
    # print(age_li)
print(f'4팀 최저연령은{min(age_li)} 최고연령은 {max(age_li)} 평균연령은 {a}')
print()
# Out:
# 민지의 평균연령은 25.0
# 승은의 평균연령은 20.0
# 선민의 평균연령은 23.0
# 4팀 최저연령은18 최고연령은 27 평균연령은 23.0

# %%
alist = {
    '키1':['값1','값2']
    '키2':['값3','값4']
    '키3':['값5','값6']
    '키4':{'키':100}}
print(list(alist['키1']))
print(alist['키4']['키'])
# Out:
#   File "<ipython-input-14-536b737fd166>", line 3
#     '키2':['값3','값4']
#        ^
# SyntaxError: invalid syntax

# %%
alist = {
    '민지':[23,27], 
    '승은':[18,22], 
    '선민':[21,25]}
age_li = []
for i,v in alist.items():
    a = (min(v)+max(v))/2
    print(f'{i}의 평균연령은 {a}')
    age_li.extend(v)
    # print(age_li)
print(f'4팀 최저연령은{min(age_li)} 최고연령은 {max(age_li)} 평균연령은 {a}')
print()
# Out:
# 민지의 평균연령은 25.0
# 승은의 평균연령은 20.0
# 선민의 평균연령은 23.0
# 4팀 최저연령은18 최고연령은 27 평균연령은 23.0

# %%
a = {'민지':'이다해', '승은':'권소현', '선민':'최진실'}
print('닮은 연예인은?')
for key,value in a.items():
    print(key,value)
# Out:
# 닮은 연예인은?
# 민지 이다해
# 승은 권소현
# 선민 최진실

# %%
text = '20~24'
ageList = text.split('~')

# %%
dict = {'승훈':["이승훈", "19~23"]}


ageList = dict['승훈'][1].split("~")

intList = list(map(int, ageList))


sum(intList)
# Out:
# 42

# %%
age_list = {
    '민지':['이다해', '23~27'], 
    '승은':['권소현', '18~22'], 
    '선민':['최진실', '21~25']}

age_list = []

for i,v in age_list.items():
    ageList = dict[i][1].split("~")
    intList = list(map(int, ageList))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-8773c3c74c6b> in <module>()
#       6 age_list = []
#       7
# ----> 8 for i,v in age_list.items():
#       9     ageList = dict[i][1].split("~")
#      10     intList = list(map(int, ageList))
#
# AttributeError: 'list' object has no attribute 'items'

# %%
dic_age = {
    '승은':['권소현','18~22'],
    '선민':['최진실','21~25',],
    '민지':['이다해','23~27',]
}

age_list = []
# agesplit = dic_age[key]       #value값을 보여주기 위해서
for i,v in age_list.items():
    ageList = dic_age[i][1].split("~")
    intList = list(map(int, ageList))
    sum(intList)
    min1 = int(sum(intList)/len(i))
    max1 = int(sum(intList)/len(i))
    print(f'우리팀의 최저평균연령은 {min1}, 최고연령은 {max1}')
print(f'우리팀의 얼굴나이 평균은 {(min1+max1)/2} 입니다.')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-3615368a878f> in <module>()
#       7 age_list = []
#       8 # agesplit = dic_age[key]       #value값을 보여주기 위해서
# ----> 9 for i,v in age_list.items():
#      10     ageList = dic_age[i][1].split("~")
#      11     intList = list(map(int, ageList))
#
# AttributeError: 'list' object has no attribute 'items'

# %%
dic_age = {
    '승은':['권소현','18~22'],
    '선민':['최진실','21~25',],
    '민지':['이다해','23~27',]
}

age_list = []
# agesplit = dic_age[key]       #value값을 보여주기 위해서
for i,v in dic_age.items():
    ageList = dic_age[i][1].split("~")
    intList = list(map(int, ageList))
    sum(intList)
    min1 = int(sum(intList[0])/len(i))
    max1 = int(sum(intList)[1]/len(i))
    print(f'우리팀의 최저평균연령은 {min1}, 최고연령은 {max1}')
print(f'우리팀의 얼굴나이 평균은 {(min1+max1)/2} 입니다.')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-365df9108925> in <module>()
#      11     intList = list(map(int, ageList))
#      12     sum(intList)
# ---> 13     min1 = int(sum(intList[0])/len(i))
#      14     max1 = int(sum(intList)[1]/len(i))
#      15     print(f'우리팀의 최저평균연령은 {min1}, 최고연령은 {max1}')
#
# TypeError: 'int' object is not iterable

# %%
dic_age = {
    '승은':['권소현','18~22'],
    '선민':['최진실','21~25'],
    '민지':['이다해','23~27']
}
age_list = []
# agesplit = dic_age[key]       #value값을 보여주기 위해서
for i,v in dic_age.items():
    ageList = dic_age[i][1].split("~")
    intList = list(map(int, ageList))
    sum(intList)
min1 = int(sum(intList[0])/len(i))
max1 = int(sum(intList[1])/len(i))
print(f'우리팀의 최저평균연령은 {min1}, 최고연령은 {max1}')
print(f'우리팀의 얼굴나이 평균은 {(min1+max1)/2} 입니다.')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-e9e9f443a9dd> in <module>()
#      10     intList = list(map(int, ageList))
#      11     sum(intList)
# ---> 12 min1 = int(sum(intList[0])/len(i))
#      13 max1 = int(sum(intList[1])/len(i))
#      14 print(f'우리팀의 최저평균연령은 {min1}, 최고연령은 {max1}')
#
# TypeError: 'int' object is not iterable

# %%
dic_age = {
    '승은':['권소현','18~22'],
    '선민':['최진실','21~25',],
    '민지':['이다해','23~27',]
}

age_list = []
# agesplit = dic_age[key]       #value값을 보여주기 위해서
for i,v in dic_age.items():
    ageList = dic_age[i][1].split("~")
    intList = list(map(int, ageList))
    sum(intList)
min1 = int(sum(intList)/len(i))
max1 = int(sum(intList)/len(i))
print(f'우리팀의 최저평균연령은 {min1}, 최고연령은 {max1}')
print(f'우리팀의 얼굴나이 평균은 {(min1+max1)/2} 입니다.')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-d73a4a108d34> in <module>()
#      10     ageList = dic_age[i][1].split("~")
#      11     intList = list(map(int, ageList))
# ---> 12     sum(intList)
#      13 sum = 0
#      14 for i,v in list:
#
# TypeError: 'int' object is not callable

# %%
dic_age = {
    '승은':['권소현','18~22'],
    '선민':['최진실','21~25'],
    '민지':['이다해','23~27']
}
age_list = []
# agesplit = dic_age[key]       #value값을 보여주기 위해서
for i,v in dic_age.items():
    ageList = dic_age[i][1].split("~")
    intList = list(map(int, ageList))
    print(f'{i}의 최소나이는 {intList[0]}이고 최대나이는 {intList[1]}입니다!')
print('_'*50)
print(f'우리팀의 얼굴나이 평균은 {(min1+max1)/2} 입니다.')
# Out:
# 승은의 최소나이는 18이고 최대나이는 22입니다!
# 선민의 최소나이는 21이고 최대나이는 25입니다!
# 민지의 최소나이는 23이고 최대나이는 27입니다!
# __________________________________________________
# 우리팀의 얼굴나이 평균은 25.0 입니다.

# %%
dic_age = {
    '승은':['권소현','18~22'],
    '선민':['최진실','21~25'],
    '민지':['이다해','23~27']}
age_list = []
min0 = 0 
max0 = 0
for i,v in dic_age.items():
    ageList = dic_age[i][1].split("~")
    intList = list(map(int, ageList))
    print(f'{i}의 최소나이는 {intList[0]}이고 최대나이는 {intList[1]}입니다!')
    min0 += intList[0]
    max0 += intList[1]
print(f'우리팀의 최저평균연령은 {min0/len(dic_age)}, 최고연령은 {max0/len(dic_age)}')
print(f'우리팀의 얼굴나이 평균은 {((min0+max0)/len(dic_age))/2} 입니다.'
# Out:
#   File "<ipython-input-1-f0902bac9b9f>", line 15
#     print(f'우리팀의 얼굴나이 평균은 {((min0+max0)/len(dic_age))/2} 입니다.'
#                                                               ^
# SyntaxError: unexpected EOF while parsing

# %%
dic_age = {
    '승은':['권소현','18~22'],
    '선민':['최진실','21~25'],
    '민지':['이다해','23~27']}
age_list = []
min0 = 0
max0 = 0
for i,v in dic_age.items():
    ageList = dic_age[i][1].split("~")
    intList = list(map(int, ageList))
    print(f'{i}는 {dic_age[i][0]}이고, 최소나이는 {intList[0]}이고 최대나이는 {intList[1]}입니다!')
    min0 += intList[0]
    max0 += intList[1]
print(f'우리팀의 최저평균연령은 {round(min0/len(dic_age))}, 최고연령은 {round(max0/len(dic_age))}')
print(f'우리팀의 얼굴나이 평균은 {round(((min0+max0)/len(dic_age))/2)} 입니다.')
# Out:
# 승은는 권소현이고, 최소나이는 18이고 최대나이는 22입니다!
# 선민는 최진실이고, 최소나이는 21이고 최대나이는 25입니다!
# 민지는 이다해이고, 최소나이는 23이고 최대나이는 27입니다!
# 우리팀의 최저평균연령은 21, 최고연령은 25
# 우리팀의 얼굴나이 평균은 23 입니다.
